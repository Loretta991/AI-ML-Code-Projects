# %%
import csv
import pandas as pd
import numpy as np
df = pd.read_csv("data.csv")
FileName = open("data.csv",'r')

n= 1
for i in range(1):
  print('This is the original Housing Data file : ')   
  print(df) 
i = i - n
while n < 1:  
  df.fillna('', inplace = True)
print(df.max(), ' values')
